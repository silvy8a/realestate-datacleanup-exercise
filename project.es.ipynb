# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de fotocasa, el cual es uno de los sitios mas populares de bienes raíces en España. Por favor no hagas estos (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa mas cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa mas cara en el todo el dataset? (★☆☆)
#
# Imprime la direccion y el precio de la casa seleccionada. Por ejemplo:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
index_expensive=(ds.price.idxmax())
print(f'The house with address {ds.address[index_expensive]} is the most expensive and its price is {ds.price[index_expensive]} euros')
# Out:
# The house with address El Escorial is the most expensive and its price is 8500000 euros

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa mas barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
index_cheapest=(ds.price.idxmin())
print(f'The house with address {ds.address[index_cheapest]} is the cheapest and its price is {ds.price[index_cheapest]} euros')
# Out:
# The house with address Parla is the cheapest and its price is 0 euros

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa mas grande y la mas pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el area de las casas seleccionadas. Por ejemplo:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
index_biggest=(ds.surface.idxmax())
index_smallest=(ds.surface.idxmin())
print(f'The biggest house is located in {ds.address[index_biggest]} and its surface is {ds.surface[index_biggest]} square meters and the smallest one is located on {ds.address[index_smallest]} and its surface is {ds.surface[index_smallest]} square meters ')
# Out:
# The biggest house is located in Sevilla la Nueva and its surface is 249000.0 square meters and the smallest one is located on Calle Amparo,  Madrid Capital and its surface is 15.0 square meters

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
for item in ds['level5']:
    print(item, end= ', ')
# Out:
# Arganda del Rey, Fuenlabrada, Boadilla del Monte, Fuenlabrada, Arganda del Rey, Las Rozas de Madrid, Las Rozas de Madrid, Las Rozas de Madrid, Las Rozas de Madrid,  Madrid Capital,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero,  Madrid Capital,  Madrid Capital,  Madrid Capital, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes,  Madrid Capital, Rivas-vaciamadrid, Alpedrete,  Madrid Capital,  Madrid Capital,  Madrid Capital, Móstoles,  Madrid Capital,  Madrid Capital,  Madrid Capital, San Fernando de Henares, Coslada,  Madrid Capital, Becerril de la Sierra,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, Alcalá de Henares,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, Pinto,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, Chinchón,  Madrid Capital, Parla,  Madrid Capital, Parla,  Madrid Capital,  Madrid Capital, Alcorcón,  Madrid Capital,  Madrid Capital, Pozuelo de Alarcón, El Escorial, Pozuelo de Alarcón,  Madrid Capital,  Madrid Capital,  Madrid Capital, Leganés, Parla,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, Boadilla del Monte, Pedrezuela, Las Rozas de Madrid, Las Rozas de Madrid, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Las Rozas de Madrid, Villanueva del Pardillo, Alcorcón, Torrelodones,  Madrid Capital,  Madrid Capital, Moralzarzal,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, San Sebastián de los Reyes, Mejorada del Campo, Coslada, Coslada,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, Aranjuez,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, Moralzarzal,  Madrid Capital, Navalcarnero,  Madrid Capital, Villanueva del Pardillo,  Madrid Capital, Rivas-vaciamadrid,  Madrid Capital,  Madrid Capital,  Madrid Capital, Alcalá de Henares, Alcalá de Henares, Corpa, Alcalá de Henares,  Madrid Capital, Pozuelo de Alarcón,  Madrid Capital,  Madrid Capital,  Madrid Capital, Móstoles, Móstoles, Móstoles,  Madrid Capital,  Madrid Capital, Valdemoro,  Madrid Capital, Fuenlabrada,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, Navalcarnero,  Madrid Capital,  Madrid Capital, Getafe, Las Rozas de Madrid, Majadahonda, Majadahonda, Las Rozas de Madrid, Las Rozas de Madrid, Villanueva del Pardillo,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, Velilla de San Antonio,  Madrid Capital,  Madrid Capital, Leganés, Majadahonda,  Madrid Capital,  Madrid Capital, Leganés,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, Parla,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, Valdemoro, Valdemoro,  Madrid Capital,  Madrid Capital,  Madrid Capital, Fuenlabrada,  Madrid Capital,  Madrid Capital, Alpedrete,  Madrid Capital, Fuenlabrada, Boadilla del Monte,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital,  Madrid Capital, Fuenlabrada,  Madrid Capital, Getafe, Getafe,  Madrid Capital,  Madrid Capital, Fuenlabrada,  Madrid Capital, San Sebastián de los Reyes, Sevilla la Nueva,  Madrid Capital, Boadilla del Monte,  Madrid Capital,  ...

# %% [markdown]
# #### Ejercicio 05. ¿El data set contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`true` o `fase`) seguido de la fila/columna que contiene el NAs.

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
nan_rows = ds.isna().any(axis=1)
print(nan_rows)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 15330    True
# 15331    True
# 15332    True
# 15333    True
# 15334    True
# Length: 15335, dtype: bool

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del data set, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
new_ds = ds.dropna(axis=1)
print(f'The dimension of the original Dataframe is {ds.size} whereas after deletions the dimension of the Dataframe is {new_ds.size}')
# Out:
# The dimension of the original Dataframe is 567395 whereas after deletions the dimension of the Dataframe is 383375

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
arroyomolinos_list = ds[ds['level5'] == "Arroyomolinos (Madrid)"]
arroyomolinos_mean = arroyomolinos_list["price"].mean()
print(arroyomolinos_mean)
# Out:
# 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import pandas as pd
import matplotlib.pyplot as plt
ds = pd.read_csv('assets/real_estate.csv', sep=';')
arroyomolinos_list = ds[ds['level5'] == "Arroyomolinos (Madrid)"]
plt.figure(figsize = (10, 5))
plt.hist(arroyomolinos_list["price"], bins = 30, alpha = 0.7)
plt.title("Histograma")
plt.show()

# %% [markdown]
# El histograma muestra tres picos, todos ellos situados entre 200.000 y 400.000€ y tiene una forma relativamente simétrica (pese a la distribución multimodal), que concentra la mayor parte de sus valores entre 150.000 y 475.000€. A simple vista, parece que el pico central se alinearía bastante con la media y la mediana. También se pueden observar varios valores atípicos, pero mucho más puntuales.

# %% [markdown]
# #### Ejercicio 09. ¿ Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedio y escribe una conclusion acerca de ellos

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
valdemorillo_list = ds[ds['level5'] == "Valdemorillo"]
galapagar_list = ds[ds['level5'] == "Galapagar"]
valdemorillo_mean = valdemorillo_list["price"].mean()
galapagar_mean = galapagar_list["price"].mean()
print(valdemorillo_mean)
print(galapagar_mean)
# Out:
# 363860.2931034483
# 360063.20238095237

# %% [markdown]
# El precio promedio de la vivienda en Galapagar y Valdemorillo no es el mismo, pero no hay ni 4000€ de diferencia entre una población y la otra. De modo que podemos considerar que estas dos localidades, cuya distancia no es ni de 15k, se encuentran en la misma horquilla en lo que a los precios de pisos se refiere.

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (price/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio y escribe una conclusion acerca de ellos.
#
# Pista: Crea una nueva columna llamada `pps` (price per square) y luego analiza los valore.s

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds['pps'] = ds["price"] / ds["surface"]
valdemorillo_mean = ds[ds['level5'] == "Valdemorillo"]['pps'].mean()
galapagar_mean = ds[ds['level5'] == "Galapagar"]['pps'].mean()
print(valdemorillo_mean)
print(galapagar_mean)
# Out:
# 1317.9502109024986
# 1606.3240303094024

# %% [markdown]
# Al igual que sucede con el precio de las viviendas, el precio promedio por m2 en en Galapagar y Valdemorillo no es el mismo, pero hay una diferencia (en este caso no llega a los 300€) que sugiere que el precio a pagar por una vivienda de la misma superficie sería algo superior en Galapagar.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusion al respecto.

# %%
import pandas as pd
import matplotlib.pyplot as plt
ds = pd.read_csv('assets/real_estate.csv', sep=';')

x=ds['surface']
y=ds['price']

plt.scatter(x,y)

plt.xlabel("Surface")
plt.ylabel("Price")

plt.title("Relación entre superficie y precio")

plt.show()

# %% [markdown]
# **TODO: Markdown**. Escribe aquí, haz doble click en este celda y elimina este contenido y reemplázalo por el texto que quires escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
print(ds.realEstate_name.nunique())
# Out:
# 1821

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
results=ds['level5'].value_counts()[ds['level5'].value_counts() == ds['level5'].value_counts().max()]
print(results)
# Out:
# level5
# Madrid Capital    6643
# Name: count, dtype: int64

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Has un subconjunto del Dataframe original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Pista: Filtra el Dataframe original usando la columna `level5` y la función `isin`

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
cinturon_sur=ds.apply(lambda row: row[ds['level5'].isin(['Fuenlabrada','Leganés', 'Getafe', 'Alcorcón'])])

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barra de la media de los precios y explica lo que observas (debes usar el subconjunto obtenido de la pregunta 14) (★★★)
#
# Imprima un gráfico de barra de la media de precios y escriba en la celda Markdown un breve análisis del sector.

# %%
import pandas as pd
import matplotlib.pyplot as plt
ds = pd.read_csv('assets/real_estate.csv', sep=';')
cinturon_sur=ds.apply(lambda row: row[ds['level5'].isin(['Fuenlabrada','Leganés', 'Getafe', 'Alcorcón'])])
means=cinturon_sur.groupby('level5')['price'].mean()
print(means)
labels = ["Alcorcón", "Fuenlabrada", "Getafe", "Leganés"]
values = [230071.052632, 177198.021459, 265040.500000, 208682.010309]

plt.figure(figsize = (10, 5))

plt.bar(labels, values)

plt.title("Gráfico de barras")
plt.show()
# Out:
# level5
# Alcorcón       230071.052632
# Fuenlabrada    177198.021459
# Getafe         265040.500000
# Leganés        208682.010309
# Name: price, dtype: float64

# %% [markdown]
# A partir del gráfico de barras, establecemos que por orden de mayor a menor podemos ordenar las siguientes poblaciones, según el precio de las viviendas, del siguiente modo: Getafe, Alcorcón, Leganés y Fuenlabrada. Se trata de cuatro localidades que se encuentran dentro del área metropolitana de Madrid, a una distancia de entre 15 y 25km de la capital, de modo que es una distancia asumible para un desplazamiento diario para personas que no pueden asumir los precios de las viviendas de Madrid ciudad. De todos modos, en ningún caso encontramos viviendas disponibles por debajo de aproximadamente 170.000€.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza dela muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Imprime ambos valores por  cada variable.

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
cinturon_sur=ds.apply(lambda row: row[ds['level5'].isin(['Fuenlabrada','Leganés', 'Getafe', 'Alcorcón'])])

mean_list = cinturon_sur[['price','rooms','surface','bathrooms']].mean()
var_list = cinturon_sur[['price','rooms','surface','bathrooms']].var()

results = pd.DataFrame({'Mean': mean_list, 'Var': var_list})

print(results)
# Out:
#                     Mean           Var
# price      223094.480706  1.492137e+10
# rooms           3.017738  7.188859e-01
# surface       111.752224  4.263052e+03
# bathrooms       1.633222  5.717969e-01

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
import pandas as pd
ds = pd.read_csv('assets/real_estate.csv', sep=';')
cinturon_sur=ds.apply(lambda row: row[ds['level5'].isin(['Fuenlabrada','Leganés', 'Getafe', 'Alcorcón'])])
alcorcon_expensive=cinturon_sur[cinturon_sur['level5']== "Alcorcón"]['price'].idxmax()
fuenlabrada_expensive=cinturon_sur[cinturon_sur['level5']== "Fuenlabrada"]['price'].idxmax()
getafe_expensive=cinturon_sur[cinturon_sur['level5']== "Getafe"]['price'].idxmax()
leganes_expensive=cinturon_sur[cinturon_sur['level5']== "Leganés"]['price'].idxmax()
print(f'The house with address {cinturon_sur.address[alcorcon_expensive]} is the most expensive and its price is {cinturon_sur.price[alcorcon_expensive]} euros') 
print(f'The house with address {cinturon_sur.address[fuenlabrada_expensive]} is the most expensive and its price is {cinturon_sur.price[fuenlabrada_expensive]} euros')
print(f'The house with address {cinturon_sur.address[getafe_expensive]} is the most expensive and its price is {cinturon_sur.price[getafe_expensive]} euros')
print(f'The house with address {cinturon_sur.address[leganes_expensive]} is the most expensive and its price is {cinturon_sur.price[leganes_expensive]} euros')
# Out:
# The house with address Alcorcón is the most expensive and its price is 950000 euros
# The house with address Calle de Paulo Freire, 5, Fuenlabrada is the most expensive and its price is 490000 euros
# The house with address Getafe is the most expensive and its price is 1050000 euros
# The house with address Avenida Reina Sofía, Leganés is the most expensive and its price is 650000 euros

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
ds = pd.read_csv('assets/real_estate.csv', sep=';')
cinturon_sur=ds.apply(lambda row: row[ds['level5'].isin(['Fuenlabrada','Leganés', 'Getafe', 'Alcorcón'])])
getafe_data = cinturon_sur[cinturon_sur['level5']=="Getafe"]['price'].mean()
alcorcon_data = cinturon_sur[cinturon_sur['level5']=="Alcorcón"]['price'].mean()
leganes_data = cinturon_sur[cinturon_sur['level5']=="Leganés"]['price'].mean()
fuenlabrada_data = cinturon_sur[cinturon_sur['level5']=="Fuenlabrada"]['price'].mean()

data = [[getafe_data], [alcorcon_data], [leganes_data], [fuenlabrada_data]]

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
import pandas as pd
import matplotlib.pyplot as plt
ds = pd.read_csv('assets/real_estate.csv', sep=';')
cinturon_sur=ds.apply(lambda row: row[ds['level5'].isin(['Fuenlabrada','Leganés', 'Getafe', 'Alcorcón'])])
x=cinturon_sur[cinturon_sur['level5'] == "Alcorcón"]['surface']
y=cinturon_sur[cinturon_sur['level5'] == "Alcorcón"]['bathrooms']
x2=cinturon_sur[cinturon_sur['level5'] == "Fuenlabrada"]['surface']
y2=cinturon_sur[cinturon_sur['level5'] == "Fuenlabrada"]['bathrooms']
x3=cinturon_sur[cinturon_sur['level5'] == "Getafe"]['surface']
y3=cinturon_sur[cinturon_sur['level5'] == "Getafe"]['bathrooms']
x4=cinturon_sur[cinturon_sur['level5'] == "Leganés"]['surface']
y4=cinturon_sur[cinturon_sur['level5'] == "Leganés"]['bathrooms']

plt.scatter(x, y)
plt.scatter(x2, y2)
plt.scatter(x3, y3)
plt.scatter(x4, y4)

plt.xlabel("Surface")
plt.ylabel("Bathrooms")

plt.title("Número de baños según superfice en Cinturón Sur")
plt.legend(labels=['Alcorcón', 'Fuenlabrada', 'Getafe', 'Leganés'], bbox_to_anchor= (1.05, 0.5), loc= "lower left")
plt.show()

# %% [markdown]
# Según los cálculos, el precio por m2 es superior en Alcorcón (2239,30€) frente a Getafe (2066,31€). Teniendo en cuenta que hemos visto anteriormente que el promedio del precio de la vivienda es superior en Getafe, podríamos deducir que hay menos superficie disponible en Alcorcón.

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
import pandas as pd
import matplotlib.pyplot as plt
ds = pd.read_csv('assets/real_estate.csv', sep=';')
cinturon_sur=ds.apply(lambda row: row[ds['level5'].isin(['Fuenlabrada','Leganés', 'Getafe', 'Alcorcón'])])
x=cinturon_sur[cinturon_sur['level5'] == "Alcorcón"]['surface']
y=cinturon_sur[cinturon_sur['level5'] == "Alcorcón"]['bathrooms']
x2=cinturon_sur[cinturon_sur['level5'] == "Fuenlabrada"]['surface']
y2=cinturon_sur[cinturon_sur['level5'] == "Fuenlabrada"]['bathrooms']
x3=cinturon_sur[cinturon_sur['level5'] == "Getafe"]['surface']
y3=cinturon_sur[cinturon_sur['level5'] == "Getafe"]['bathrooms']
x4=cinturon_sur[cinturon_sur['level5'] == "Leganés"]['surface']
y4=cinturon_sur[cinturon_sur['level5'] == "Leganés"]['bathrooms']

plt.scatter(x, y)
plt.scatter(x2, y2)
plt.scatter(x3, y3)
plt.scatter(x4, y4)

plt.xlabel("Surface")
plt.ylabel("Bathrooms")

plt.title("Número de baños según superfice en Cinturón Sur")
plt.legend(labels=['Alcorcón', 'Fuenlabrada', 'Getafe', 'Leganés'], bbox_to_anchor= (1.05, 0.5), loc= "lower left")
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón ur de Madrid por color d cada población (debes usar el subconjunto obtenido en la pregunta 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar u código simple que transforme las columnas de coordenadas en un diccionario de python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en (60 grados latitud et -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:
